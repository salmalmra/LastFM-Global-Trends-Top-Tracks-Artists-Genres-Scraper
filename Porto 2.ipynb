# %% [markdown]
# # **Portofolio 2**

# %%
from dotenv import load_dotenv
import os
import pandas as pd
import requests
import time
from datetime import datetime, timedelta

#Bigquery Connection
from google.oauth2 import service_account
import pandas_gbq

import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_columns', None)

# %%
BASE_URL = "https://www.last.fm/api"

# %%
# Configuration 
LASTFM_API_KEY = os.getenv('LASTFM_API_KEY')

# %%
# Last.FM API base URL
LASTFM_API_URL = 'http://ws.audioscrobbler.com/2.0/'

# %%
# load the .env file
load_dotenv("D:\\Purwadhika\\Portofolio\\.env")

# read the key
LASTFM_API_KEY = os.getenv("LASTFM_API_KEY")
print(LASTFM_API_KEY)
# Out:
# 5e037de975e0eb13e723be687f70ea98

# %% [markdown]
# ## **Fungsi**

# %%
def get_top_tracks(limit=100, period='overall'):
    """
    Fetch top tracks globally from Last.fm
    
    Args:
        limit (int): Number of tracks to fetch
        period (str): Time period - overall, 12month, 6month, 3month, 1month, 7day
    
    Returns:
        list: List of top tracks
    """
    params = {
        'method': 'chart.gettoptracks',
        'api_key': LASTFM_API_KEY,
        'format': 'json',
        'limit': limit
    }
    
    try:
        print(f"   Fetching top {limit} global tracks...")
        response = requests.get(LASTFM_API_URL, params=params)
        response.raise_for_status()
        data = response.json()
        
        tracks = data.get('tracks', {}).get('track', [])
        if isinstance(tracks, dict):
            tracks = [tracks]
        
        return tracks
    
    except requests.exceptions.RequestException as e:
        print(f"Error fetching top tracks: {e}")
        return []

# %% [markdown]
# Fungsi ini adalah utility yang robust untuk mengambil data lagu-lagu populer dari Last.fm dengan error handling yang baik, meskipun parameter period tidak digunakan dalam implementasi saat ini.

# %%
def get_top_artists(limit=100):
    """
    Fetch top artists globally from Last.fm
    
    Args:
        limit (int): Number of artists to fetch
    
    Returns:
        list: List of top artists
    """
    params = {
        'method': 'chart.gettopartists',
        'api_key': LASTFM_API_KEY,
        'format': 'json',
        'limit': limit
    }
    
    try:
        print(f"   Fetching top {limit} global artists...")
        response = requests.get(LASTFM_API_URL, params=params)
        response.raise_for_status()
        data = response.json()
        
        artists = data.get('artists', {}).get('artist', [])
        if isinstance(artists, dict):
            artists = [artists]
        
        return artists
    
    except requests.exceptions.RequestException as e:
        print(f"Error fetching top artists: {e}")
        return []

# %% [markdown]
# Fungsi ini adalah utility yang simpel dan efektif untuk mengambil data artis populer dari Last.fm. Strukturnya hampir identik dengan get_top_tracks(), menunjukkan konsistensi dalam design pattern untuk API calls dalam aplikasi ini.

# %%
def get_top_tags(limit=100):
    """
    Fetch top tags (genres) globally from Last.fm
    
    Args:
        limit (int): Number of tags to fetch
    
    Returns:
        list: List of top tags
    """
    params = {
        'method': 'chart.gettoptags',
        'api_key': LASTFM_API_KEY,
        'format': 'json',
        'limit': limit
    }
    
    try:
        print(f"   Fetching top {limit} global genres...")
        response = requests.get(LASTFM_API_URL, params=params)
        response.raise_for_status()
        data = response.json()
        
        tags = data.get('tags', {}).get('tag', [])
        if isinstance(tags, dict):
            tags = [tags]
        
        return tags
    
    except requests.exceptions.RequestException as e:
        print(f"Error fetching top tags: {e}")
        return []

# %% [markdown]
# Fungsi get_top_tags() adalah komponen penting untuk:
#
# Genre Analysis: Memahami tren genre musik
# Music Categorization: Mengkategorikan konten musik
# Trend Discovery: Menemukan tren baru dalam musik
# Recommendation Systems: Basis untuk sistem rekomendasi
# Strukturnya konsisten dengan fungsi API lain dalam aplikasi, memudahkan maintenance dan menunjukkan good coding practices dengan pattern yang seragam.

# %%
def get_artist_info(artist_name):
    """
    Fetch detailed info about an artist including country
    
    Args:
        artist_name (str): Name of the artist
    
    Returns:
        dict: Artist information
    """
    params = {
        'method': 'artist.getinfo',
        'artist': artist_name,
        'api_key': LASTFM_API_KEY,
        'format': 'json'
    }
    
    try:
        response = requests.get(LASTFM_API_URL, params=params)
        response.raise_for_status()
        return response.json().get('artist', {})
    
    except requests.exceptions.RequestException as e:
        print(f"Error fetching artist info for {artist_name}: {e}")
        return {}

# %% [markdown]
# get_artist_info() adalah fungsi utility yang clean dan simple untuk mendapatkan informasi detail artis. Meskipun docstring menyebut "including country", fungsi ini tidak benar-benar mengembalikan data country karena keterbatasan Last.fm API. Fungsi ini cocok untuk:
#
# Building artist profiles
# Getting artist statistics
# Finding similar artists
# Extracting artist biography
# Getting artist tags/genres
# Strukturnya lebih sederhana dibanding fungsi get_top_*() karena hanya handle single entity, tapi tetap maintain error handling pattern yang konsisten.

# %%
def get_track_tags(artist_name, track_name):
    """
    Fetch genres/tags for a specific track
    
    Args:
        artist_name (str): Name of the artist
        track_name (str): Name of the track
    
    Returns:
        str: Comma-separated genre names
    """
    params = {
        'method': 'track.gettoptags',
        'artist': artist_name,
        'track': track_name,
        'api_key': LASTFM_API_KEY,
        'format': 'json'
    }
    
    try:
        response = requests.get(LASTFM_API_URL, params=params)
        response.raise_for_status()
        data = response.json()
        
        tags = data.get('toptags', {}).get('tag', [])
        if isinstance(tags, dict):
            tags = [tags]
        
        # Extract just the tag names (top 5 genres)
        tag_names = [tag.get('name') for tag in tags[:5]]
        return ', '.join(tag_names) if tag_names else 'Unknown'
    
    except requests.exceptions.RequestException as e:
        print(f"Error fetching tags for {track_name}: {e}")
        return 'Unknown'

# %% [markdown]
# get_track_tags() adalah fungsi utility yang specialized untuk mendapatkan genre/tags sebuah lagu dalam format yang langsung readable (string).

# %%
def organize_top_tracks(tracks):
    """
    organize top tracks into DataFrame with genres
    
    Args:
        tracks (list): List of track dictionaries
    
    Returns:
        pd.DataFrame: organized tracks data
    """
    organized_tracks = []
    
    for idx, track in enumerate(tracks, 1):
        try:
            artist_name = track.get('artist', {}).get('name') if isinstance(track.get('artist'), dict) else track.get('artist')
            track_name = track.get('name')
            
            # Fetch genre tags
            print(f"      Fetching genres for {track_name}...", end=' ', flush=True)
            genres = get_track_tags(artist_name, track_name)
            print("✓")
            time.sleep(0.1)  # Rate limiting
            
            organized_track = {
                'rank': idx,
                'track_name': track_name,
                'artist': artist_name,
                'genres': genres,
                'playcount': int(track.get('playcount', 0)),
                'listeners': int(track.get('listeners', 0)),
                'url': track.get('url'),
                'data_type': 'top_track',
                'extracted_at': datetime.utcnow()
            }
            organized_tracks.append(organized_track)
        
        except (KeyError, ValueError, TypeError) as e:
            print(f"Error parsing track: {e}")
            continue
    
    return pd.DataFrame(organized_tracks)

# %% [markdown]
# organize_top_tracks() adalah fungsi data transformation yang crucial dalam pipeline, bertindak sebagai bridge antara raw API data dan analytical-ready DataFrame.

# %%
def organize_top_artists(artists):
    """
    organize top artists into DataFrame with country info
    
    Args:
        artists (list): List of artist dictionaries
    
    Returns:
        pd.DataFrame: organized artists data
    """
    organized_artists = []
    
    for idx, artist in enumerate(artists, 1):
        try:
            artist_name = artist.get('name')
            
            # Fetch detailed info to get country
            print(f"      Fetching details for {artist_name}...", end=' ', flush=True)
            artist_info = get_artist_info(artist_name)
            
            country = None
            if artist_info and 'country' in artist_info:
                country = artist_info.get('country')
            
            print("✓")
            time.sleep(0.1)  # Rate limiting
            
            organized_artist = {
                'rank': idx,
                'artist_name': artist_name,
                'country': country,
                'playcount': int(artist.get('playcount', 0)),
                'listeners': int(artist.get('listeners', 0)),
                'url': artist.get('url'),
                'data_type': 'top_artist',
                'extracted_at': datetime.utcnow()
            }
            organized_artists.append(organized_artist)
        
        except (KeyError, ValueError, TypeError) as e:
            print(f"Error parsing artist: {e}")
            continue
    
    return pd.DataFrame(organized_artists)

# %% [markdown]
# organize_top_artists() memiliki fundamental flaw - mencoba mengambil data country yang tidak tersedia di Last.fm API

# %%
def organize_top_tags(tags):
    """
    organize top tags/genres into DataFrame
    
    Args:
        tags (list): List of tag dictionaries
    
    Returns:
        pd.DataFrame: organized tags data
    """
    organized_tags = []
    
    for idx, tag in enumerate(tags, 1):
        try:
            # Handle reach count
            reach_value = tag.get('reach', 0)
            
            organized_tag = {
                'rank': idx,
                'genre': tag.get('name'),
                'reach': int(reach_value) if reach_value else 0,
                'url': tag.get('url'),
                'data_type': 'top_genre',
                'extracted_at': datetime.utcnow()
            }
            organized_tags.append(organized_tag)
        
        except (KeyError, ValueError, TypeError) as e:
            print(f"Error parsing tag: {e}")
            continue
    
    return pd.DataFrame(organized_tags)

# %%
def main():
    """Main pipeline execution"""
    
    print("=" * 60)
    print("Last.fm Global Data → DataFrames")
    print("=" * 60)
    
    # Validate configuration
    if not LASTFM_API_KEY:
        print("Error: LASTFM_API_KEY not found in .env file.")
        return
    
    # Fetch and organize Top Tracks
    print("\n🎵 FETCHING TOP TRACKS")
    print("-" * 60)
    top_tracks = get_top_tracks(limit=100)
    if top_tracks:
        df_tracks = organize_top_tracks(top_tracks)
        
        print(f"   organized {len(df_tracks)} tracks")
        print(f"\n   Sample:")
        print(df_tracks[['rank', 'track_name', 'artist', 'genres', 'playcount']].head(10))
    else:
        df_tracks = pd.DataFrame()
    
    # Fetch and organize Top Artists
    print("\n\n🎤 FETCHING TOP ARTISTS (WITH COUNTRIES)")
    print("-" * 60)
    top_artists = get_top_artists(limit=50)
    if top_artists:
        df_artists = organize_top_artists(top_artists)
        print(f"   organized {len(df_artists)} artists")
        print(f"\n   Sample:")
        print(df_artists[['rank', 'artist_name', 'country', 'listeners']].head())
    else:
        df_artists = pd.DataFrame()
    
    # Fetch and organize Top Tags/Genres
    print("\n\n🎼 FETCHING TOP GENRES")
    print("-" * 60)
    top_tags = get_top_tags(limit=100)
    if top_tags:
        df_tags = organize_top_tags(top_tags)
        print(f"   organized {len(df_tags)} genres")
        print(f"\n   Sample:")
        print(df_tags[['rank', 'genre', 'reach']].head())
    else:
        df_tags = pd.DataFrame()
    
    print("\n" + "=" * 60)
    print("✅ Pipeline completed!")
    print("=" * 60)
    
    return df_tracks, df_artists, df_tags

if __name__ == '__main__':
    df_tracks, df_artists, df_genres = main()
# Out:
# ============================================================
# Last.fm Global Data → DataFrames
# ============================================================
#
# 🎵 FETCHING TOP TRACKS
# ------------------------------------------------------------
#    Fetching top 100 global tracks...
#       Fetching genres for The Fate of Ophelia... ✓
#       Fetching genres for Last Christmas... ✓
#       Fetching genres for back to friends... ✓
#       Fetching genres for End of Beginning... ✓
#       Fetching genres for No One Noticed... ✓
#       Fetching genres for Sienna... ✓
#       Fetching genres for Good Luck, Babe!... ✓
#       Fetching genres for Manchild... ✓
#       Fetching genres for Creep... ✓
#       Fetching genres for Tears... ✓
#       Fetching genres for WHERE IS MY HUSBAND!... ✓
#       Fetching genres for The Less I Know the Better... ✓
#       Fetching genres for All I Want for Christmas Is You... ✓
#       Fetching genres for Let Down... ✓
#       Fetching genres for Dracula... ✓
#       Fetching genres for BIRDS OF A FEATHER... ✓
#       Fetching genres for Fame Is a Gun... ✓
#       Fetching genres for Gabriela... ✓
#       Fetching genres for Rockin' Around the Christmas Tree... ✓
#       Fetching genres for 505... ✓
#       Fetching genres for So Easy (To Fall In Love)... ✓
#       Fetching genres for Sweater Weather... ✓
#       Fetching genres for Man I Need... ✓
#       Fetching genres for Golden... ✓
#       Fetching genres for luther (with SZA)... ✓
#       Fetching genres for No Surprises... ✓
#       Fetching genres for Every Breath You Take... ✓
#       Fetching genres for Lovers Rock... ✓
#       Fetching genres for Gnarly... ✓
#       Fetching genres for Sports car... ✓
#       Fetching genres for Timeless (Feat Playboi Carti)... ✓
#       Fetching genres for The Subway... ✓
#       Fetching genres for When Did You Get Hot?... ✓
#       Fetching genres for Santa Tell Me... ✓
#       Fetching genres for Feel Good Inc.... ✓
#       Fetching genres for No Pole... ✓
#       Fetching genres for undressed... ✓
#       Fetching genres for House Tour... ✓
#       Fetching genres for Lover, You Should've Come Over... ✓
#       Fetching genres for All I Need... ✓
#       Fetching genres for Iris... ✓
#       Fetching genres for Sparks... ✓
#       Fetching genres for WILDFLOWER... ✓
#       Fetching genres for Opalite... ✓
#       Fetching genres for Phantom... ✓
#       Fetching genres for See You Again (feat. Kali Uchis)... ✓
#       Fetching genres for NOT CUTE ANYMORE... ✓
#       Fetching genres for Diet Pepsi... ✓
#       Fetching genres for Nobody’s Son... ✓
#       Fetching genres for Jingle Bell Rock... ✓
#       Fetching genres for Dreams - 2004 Remaster... ✓
#       Fetching genres for SUGAR ON MY TONGUE... ✓
#       Fetching genres for Espresso... ✓
#       Fetching genres for Apocalypse... ✓
#       Fetching genres for 4 Raws... ✓
#       Fetching genres for Abracadabra... ✓
#       Fetching genres for Juno... ✓
#       Fetching genres for Running Up That Hill (A Deal with God)... ✓
#       Fetching genres for There Is a Light That Never Goes Out - 2011 Remaster... ✓
#       Fetching genres for Duvet... ✓
#       Fetching genres for From the Start... ✓
#       Fetching genres for SPAGHETTI... ✓
#       Fetching genres for Pink + White... ✓
#       Fetching genres for Borderline... ✓
#       Fetching genres for Von dutch... ✓
#       Fetching genres for party 4 u... ✓
#       Fetching genres for Taste... ✓
#       Fetching genres for Like Him (feat. Lola Young)... ✓
#       Fetching genres for Let It Snow! Let It Snow! Let It Snow!... ✓
#       Fetching genres for Love Me Not... ✓
#       Fetching genres for The Chain - 2004 Remaster... ✓
#       Fetching genres for CHANEL... ✓
#       Fetching genres for LES... ✓
#       Fetching genres for LV Sandals... ✓
#       Fetching genres for we can't be friends (wait for your love)... ✓
#       Fetching genres for Headlock... ✓
#       Fetching genres for Juna... ✓
#       Fetching genres for Berghain... ✓
#       Fetching genres for the perfect pair... ✓
#       Fetching genres for Busy Woman... ✓
#       Fetching genres for Heavy... ✓
#       Fetching genres for When the Sun Hits... ✓
#       Fetching genres for Flashing Lights... ✓
#       Fetching genres for Jigsaw Falling Into Place... ✓
#       Fetching genres for 12 to 12... ✓
#       Fetching genres for Fade Into You... ✓
#       Fetching genres for One of the Girls (with JENNIE, Lily Rose Depp)... ✓
#       Fetching genres for Heaven Knows I'm Miserable Now - 2011 Remaster... ✓
#       Fetching genres for TIT FOR TAT... ✓
#       Fetching genres for Underneath the Tree... ✓
#       Fetching genres for Mr. Brightside... ✓
#       Fetching genres for SLOW DANCING IN THE DARK... ✓
#       Fetching genres for Linger... ✓
#       Fetching genres for like JENNIE... ✓
#       Fetching genres for Back to the Old House - 2011 Remaster... ✓
#       Fetching genres for Bed Chem... ✓
#       Fetching genres for Sailor Song... ✓
#       Fetching genres for Sextape... ✓
#       Fetching genres for My Own Summer (Shove It)... ✓
#       Fetching genres for Guess featuring billie eilish... ✓
#    organized 100 tracks
#
#    Sample:
#    rank           track_name             artist  \
# 0     1  The Fate of Ophelia       Taylor Swift
# 1     2       Last Christmas              Wham!
# 2     3      back to friends              sombr
# 3     4     End of Beginning                Djo
# 4     5       No One Noticed         The Marías
# 5     6               Sienna         The Marías
# 6     7     Good Luck, Babe!      Chappell Roan
# 7     8             Manchild  Sabrina Carpenter
# 8     9                Creep          Radiohead
# 9    10                Tears  Sabrina Carpenter
#
#                                               genres  playcount
# 0  pop, best of 2025, dance-pop, power pop, synthpop   15914357
# 1                    christmas, 80s, pop, xmas, Wham   14371272
# 2  WSUM 91.7 FM Madison, rock and roll over, The ...   18617293
# 3     indie, pop, best of 2022, indie pop, synth-pop   27013875
# 4  dream pop, Neo-Psychedelia, bedroom pop, Sophi...   27765505
# 5    dream pop, alt-pop, bedroom pop, soft rock, Yay   14809249
# 6     synthpop, baroque pop, new wave, pop rock, pop   55016235
# 7   pop, rnb, country pop, female vocalist, misandry   17609148
# 8  alternative, alternative rock, rock, indie, ra...   54992749
# 9                      pop, sexy, 2025, 2020s, Disco   10854486
#
#
# 🎤 FETCHING TOP ARTISTS (WITH COUNTRIES)
# ------------------------------------------------------------
#    Fetching top 50 global artists...
#       Fetching details for Ariana Grande... ✓
#       Fetching details for The Weeknd... ✓
#       Fetching details for Radiohead... ✓
#       Fetching details for Kendrick Lamar... ✓
# 46    47         Don Toliver    None   222125334    2309879
# 47    48             Nirvana    None   556428702    7333740
# 48    49             Beyoncé    None   666962992    6220420
# 49    50         Mac DeMarco    None   321499476    3096340
#
#                                              url   data_type  \
# 0        https://www.last.fm/music/Ariana+Grande  top_artist
# 1           https://www.last.fm/music/The+Weeknd  top_artist
# 2            https://www.last.fm/music/Radiohead  top_artist
# 3       https://www.last.fm/music/Kendrick+Lamar  top_artist
# 4         https://www.last.fm/music/Taylor+Swift  top_artist
# 5   https://www.last.fm/music/Tyler,+The+Creator  top_artist
# 6    https://www.last.fm/music/Sabrina+Carpenter  top_artist
# 7            https://www.last.fm/music/Lady+Gaga  top_artist
# 8           https://www.last.fm/music/Kanye+West  top_artist
# 9                https://www.last.fm/music/Drake  top_artist
# 10       https://www.last.fm/music/Billie+Eilish  top_artist
# 11          https://www.last.fm/music/Charli+xcx  top_artist
# 12             https://www.last.fm/music/Rihanna  top_artist
# 13         https://www.last.fm/music/Tame+Impala  top_artist
# 14        https://www.last.fm/music/Lana+Del+Rey  top_artist
# 15      https://www.last.fm/music/Arctic+Monkeys  top_artist
# 16         https://www.last.fm/music/Frank+Ocean  top_artist
# 17       https://www.last.fm/music/Justin+Bieber  top_artist
# 18       https://www.last.fm/music/Chappell+Roan  top_artist
# 19            https://www.last.fm/music/Paramore  top_artist
# 20     https://www.last.fm/music/The+Mar%C3%ADas  top_artist
# 21            https://www.last.fm/music/Doja+Cat  top_artist
# 22   https://www.last.fm/music/The+Neighbourhood  top_artist
# 23      https://www.last.fm/music/PinkPantheress  top_artist
# 24            https://www.last.fm/music/Gorillaz  top_artist
# 25          https://www.last.fm/music/The+Smiths  top_artist
# 26        https://www.last.fm/music/Travis+Scott  top_artist
# 27            https://www.last.fm/music/Deftones  top_artist
# 28       https://www.last.fm/music/Fleetwood+Mac  top_artist
# 29                 https://www.last.fm/music/SZA  top_artist
# 30            https://www.last.fm/music/Coldplay  top_artist
# 31       https://www.last.fm/music/Playboi+Carti  top_artist
# 32         https://www.last.fm/music/Linkin+Park  top_artist
# 33              https://www.last.fm/music/Clairo  top_artist
# 34    https://www.last.fm/music/Childish+Gambino  top_artist
# 35      https://www.last.fm/music/Olivia+Rodrigo  top_artist
# 36              https://www.last.fm/music/Mitski  top_artist
# 37     https://www.last.fm/music/Michael+Jackson  top_artist
# 38              https://www.last.fm/music/Future  top_artist
# 39          https://www.last.fm/music/A$AP+Rocky  top_artist
# 40               https://www.last.fm/music/Lorde  top_artist
# 41             https://www.last.fm/music/TV+Girl  top_artist
# 42          https://www.last.fm/music/Tate+McRae  top_artist
# 43          https://www.last.fm/music/Bruno+Mars  top_artist
# 44         https://www.last.fm/music/beabadoobee  top_artist
# 45              https://www.last.fm/music/Laufey  top_artist
# 46         https://www.last.fm/music/Don+Toliver  top_artist
# 47             https://www.last.fm/music/Nirvana  top_artist
# 48        https://www.last.fm/music/Beyonc%C3%A9  top_artist
# 49         https://www.last.fm/music/Mac+DeMarco  top_artist
#
#                  extracted_at
# 0  2025-12-10 15:38:52.435897
# 3  2025-12-10 15:39:12.333319
# 4  2025-12-10 15:39:12.333323
# ..                        ...
# 95 2025-12-10 15:39:12.333606
# 96 2025-12-10 15:39:12.333608
# 97 2025-12-10 15:39:12.333609
# 98 2025-12-10 15:39:12.333611
# 99 2025-12-10 15:39:12.333612
#
# [100 rows x 6 columns]

# %% [markdown]
# ## **Data Cleaning**

# %%
df_tracks[['track_name', 'artist', 'genres']].head()
df_tracks['genres'][0]
# Out:
# 0             pop
# 0    best of 2025
# 0       dance-pop
# 0       power pop
# 0        synthpop
# Name: genres, dtype: object

# %%
df_tracks['genres'] = df_tracks['genres'].astype(str)

cleaned_genres = []

for g in df_tracks['genres']:
    text = str(g).strip().lower()
    if text == "" or text == "none" or text == "nan":
        cleaned_genres.append(None)
    else:
        cleaned_genres.append(text)

df_tracks['genres_clean'] = cleaned_genres

# %%
df_tracks = df_tracks.drop_duplicates(
    subset=['track_name', 'artist', 'genres_clean']
)

# %%
import pandas as pd

track_genres_dict = {}

for i in range(len(df_tracks)):
    track = df_tracks.iloc[i]['track_name']
    artist = df_tracks.iloc[i]['artist']
    genre = df_tracks.iloc[i]['genres_clean']

    key = (track, artist)

    if key not in track_genres_dict:
        track_genres_dict[key] = []

    if genre is not None and genre not in track_genres_dict[key]:
        track_genres_dict[key].append(genre)

# %%
rows = []

for key in track_genres_dict:
    track, artist = key
    genres_list = track_genres_dict[key]

    if len(genres_list) > 0:
        genres_str = ", ".join(genres_list)
        primary_genre = genres_list[0]
    else:
        genres_str = None
        primary_genre = "unknown"

    rows.append({
        'track_name': track,
        'artist': artist,
        'genres_list': genres_list,
        'genres_str': genres_str,
        'primary_genre': primary_genre
    })

df_tracks_clean = pd.DataFrame(rows)

# %%
df_tracks_clean.head()
df_tracks_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   track_name     100 non-null    object
#  1   artist         100 non-null    object
#  2   genres_list    100 non-null    object
#  3   genres_str     100 non-null    object
#  4   primary_genre  100 non-null    object
# dtypes: object(5)
# memory usage: 4.0+ KB

# %%
df_artists.head()
df_artists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rank          50 non-null     int64
#  1   artist_name   50 non-null     object
#  2   country       0 non-null      object
#  3   playcount     50 non-null     int64
#  4   listeners     50 non-null     int64
#  5   url           50 non-null     object
#  6   data_type     50 non-null     object
#  7   extracted_at  50 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(4)
# memory usage: 3.3+ KB

# %%
df_artists_clean = df_artists.copy()

# %%
df_artists_clean['rank'] = pd.to_numeric(df_artists_clean['rank'], errors='coerce')
df_artists_clean['listeners'] = pd.to_numeric(df_artists_clean['listeners'], errors='coerce')

# %%
df_artists_clean = df_artists_clean.dropna(subset=['rank'])

# %%
df_artists_clean['listeners'] = df_artists_clean['listeners'].fillna(0)

# %%
df_artists_clean['artist_name'] = df_artists_clean['artist_name'].astype(str).str.strip()

# %%
cleaned_country = []

for c in df_artists_clean['country']:
    if c is None:
        cleaned_country.append("Unknown")
    else:
        text = str(c).strip()
        if text == "":
            cleaned_country.append("Unknown")
        else:
            cleaned_country.append(text)

df_artists_clean['country'] = cleaned_country

# %%
df_artists_clean.head()
df_artists_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rank          50 non-null     int64
#  1   artist_name   50 non-null     object
#  2   country       50 non-null     object
#  3   playcount     50 non-null     int64
#  4   listeners     50 non-null     int64
#  5   url           50 non-null     object
#  6   data_type     50 non-null     object
#  7   extracted_at  50 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(4)
# memory usage: 3.3+ KB

# %%
df_genres.head()
df_genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rank          100 non-null    int64
#  1   genre         100 non-null    object
#  2   reach         100 non-null    int64
#  3   url           100 non-null    object
#  4   data_type     100 non-null    object
#  5   extracted_at  100 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 4.8+ KB

# %%
df_genres_clean = df_genres.copy()

# %%
df_genres_clean['rank'] = pd.to_numeric(df_genres_clean['rank'], errors='coerce')
df_genres_clean['reach'] = pd.to_numeric(df_genres_clean['reach'], errors='coerce')

# %%
df_genres_clean = df_genres_clean.dropna(subset=['rank'])

# %%
df_genres_clean['reach'] = df_genres_clean['reach'].fillna(0)

# %%
cleaned_genre = []

for g in df_genres_clean['genre']:
    if g is None:
        cleaned_genre.append(None)
    else:
        cleaned_genre.append(str(g).strip().lower())

df_genres_clean['genre'] = cleaned_genre

# %%
df_genres_clean = df_genres_clean.drop_duplicates(subset=['genre'])

# %%
df_genres_clean.head()
df_genres_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rank          100 non-null    int64
#  1   genre         100 non-null    object
#  2   reach         100 non-null    int64
#  3   url           100 non-null    object
#  4   data_type     100 non-null    object
#  5   extracted_at  100 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 4.8+ KB

# %%
df_tracks_bq = df_tracks_clean.drop(columns=['genres_list'])

# %%
df_tracks_bq.head()
df_tracks_bq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   track_name     100 non-null    object
#  1   artist         100 non-null    object
#  2   genres_str     100 non-null    object
#  3   primary_genre  100 non-null    object
# dtypes: object(4)
# memory usage: 3.3+ KB

# %% [markdown]
# ## **Upload Big Query**

# %%
df_tracks_bq = df_tracks.merge(
    df_artists[['artist_name', 'playcount', 'listeners']],
    left_on='artist',
    right_on='artist_name',
    how='left'
)

df_tracks_bq.drop(columns=['artist_name'], inplace=True)

print(df_tracks_bq.info())
print(df_tracks_bq.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rank          481 non-null    int64
#  1   track_name    481 non-null    object
#  2   artist        481 non-null    object
#  3   genres        481 non-null    object
#  4   playcount_x   481 non-null    int64
#  5   listeners_x   481 non-null    int64
#  6   url           481 non-null    object
#  7   data_type     481 non-null    object
#  8   extracted_at  481 non-null    datetime64[ns]
#  9   genres_clean  481 non-null    object
#  10  playcount_y   292 non-null    float64
#  11  listeners_y   292 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(6)
# memory usage: 45.2+ KB
# None
#    rank           track_name        artist        genres  playcount_x  \
# 0     1  The Fate of Ophelia  Taylor Swift           pop     15914357
# 1     1  The Fate of Ophelia  Taylor Swift  best of 2025     15914357
# 2     1  The Fate of Ophelia  Taylor Swift     dance-pop     15914357
# 3     1  The Fate of Ophelia  Taylor Swift     power pop     15914357
# 4     1  The Fate of Ophelia  Taylor Swift      synthpop     15914357
#
#    listeners_x                                                url  data_type  \
# 0       779603  https://www.last.fm/music/Taylor+Swift/_/The+F...  top_track
# 1       779603  https://www.last.fm/music/Taylor+Swift/_/The+F...  top_track
# 2       779603  https://www.last.fm/music/Taylor+Swift/_/The+F...  top_track
# 3       779603  https://www.last.fm/music/Taylor+Swift/_/The+F...  top_track
# 4       779603  https://www.last.fm/music/Taylor+Swift/_/The+F...  top_track
#
#                 extracted_at  genres_clean   playcount_y  listeners_y
# 0 2025-12-10 15:37:43.689593           pop  3.486190e+09    5732609.0
#                                              url   data_type  \
# 0        https://www.last.fm/music/Ariana+Grande  top_artist
# 1           https://www.last.fm/music/The+Weeknd  top_artist
# 2            https://www.last.fm/music/Radiohead  top_artist
# 3       https://www.last.fm/music/Kendrick+Lamar  top_artist
# 4         https://www.last.fm/music/Taylor+Swift  top_artist
# 5   https://www.last.fm/music/Tyler,+The+Creator  top_artist
# 6    https://www.last.fm/music/Sabrina+Carpenter  top_artist
# 7            https://www.last.fm/music/Lady+Gaga  top_artist
# 8           https://www.last.fm/music/Kanye+West  top_artist
# 9                https://www.last.fm/music/Drake  top_artist
# 10       https://www.last.fm/music/Billie+Eilish  top_artist
# 11          https://www.last.fm/music/Charli+xcx  top_artist
# 12             https://www.last.fm/music/Rihanna  top_artist
# 13         https://www.last.fm/music/Tame+Impala  top_artist
# 14        https://www.last.fm/music/Lana+Del+Rey  top_artist
# 15      https://www.last.fm/music/Arctic+Monkeys  top_artist
# 16         https://www.last.fm/music/Frank+Ocean  top_artist
# 17       https://www.last.fm/music/Justin+Bieber  top_artist
# 18       https://www.last.fm/music/Chappell+Roan  top_artist
# 19            https://www.last.fm/music/Paramore  top_artist
# 20     https://www.last.fm/music/The+Mar%C3%ADas  top_artist
# 21            https://www.last.fm/music/Doja+Cat  top_artist
# 22   https://www.last.fm/music/The+Neighbourhood  top_artist
# 23      https://www.last.fm/music/PinkPantheress  top_artist
# 24            https://www.last.fm/music/Gorillaz  top_artist
# 25          https://www.last.fm/music/The+Smiths  top_artist
# 26        https://www.last.fm/music/Travis+Scott  top_artist
# 27            https://www.last.fm/music/Deftones  top_artist
# 28       https://www.last.fm/music/Fleetwood+Mac  top_artist
# 29                 https://www.last.fm/music/SZA  top_artist
# 30            https://www.last.fm/music/Coldplay  top_artist
# 31       https://www.last.fm/music/Playboi+Carti  top_artist
# 32         https://www.last.fm/music/Linkin+Park  top_artist
# 33              https://www.last.fm/music/Clairo  top_artist
# 34    https://www.last.fm/music/Childish+Gambino  top_artist
# 35      https://www.last.fm/music/Olivia+Rodrigo  top_artist
# 36              https://www.last.fm/music/Mitski  top_artist
# 37     https://www.last.fm/music/Michael+Jackson  top_artist
# 38              https://www.last.fm/music/Future  top_artist
# 39          https://www.last.fm/music/A$AP+Rocky  top_artist
# 40               https://www.last.fm/music/Lorde  top_artist
# 41             https://www.last.fm/music/TV+Girl  top_artist
# 42          https://www.last.fm/music/Tate+McRae  top_artist
# 43          https://www.last.fm/music/Bruno+Mars  top_artist
# 44         https://www.last.fm/music/beabadoobee  top_artist
# 45              https://www.last.fm/music/Laufey  top_artist
# 46         https://www.last.fm/music/Don+Toliver  top_artist
# 47             https://www.last.fm/music/Nirvana  top_artist
# 48        https://www.last.fm/music/Beyonc%C3%A9  top_artist
# 49         https://www.last.fm/music/Mac+DeMarco  top_artist
#
#                  extracted_at
# 0  2025-12-10 15:38:52.435897
# 1  2025-12-10 15:38:52.807800
# 2  2025-12-10 15:38:53.232102
# 3  2025-12-10 15:38:53.677101
# 4  2025-12-10 15:38:54.053056
# 5  2025-12-10 15:38:54.465884
# 97 2025-12-10 15:39:12.333609
# 98 2025-12-10 15:39:12.333611
# 99 2025-12-10 15:39:12.333612
#
# [100 rows x 6 columns]

# %%
key_path = "d:\\Purwadhika\\Portofolio\\portofolio-2-480507-784a4cbb0d43.json"

# %%
project_id = "portofolio-2-480507"

# %%
dataset_id = "data_lastfm_porto2"

# %%
pip install pandas_gbq
# Out:
# Requirement already satisfied: pandas_gbq in c:\users\salma\miniconda3\lib\site-packages (0.30.0)
# Requirement already satisfied: setuptools in c:\users\salma\miniconda3\lib\site-packages (from pandas_gbq) (78.1.1)
# Requirement already satisfied: db-dtypes<2.0.0,>=1.0.4 in c:\users\salma\miniconda3\lib\site-packages (from pandas_gbq) (1.4.3)
# Requirement already satisfied: numpy>=1.18.1 in c:\users\salma\miniconda3\lib\site-packages (from pandas_gbq) (2.3.3)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\salma\miniconda3\lib\site-packages (from pandas_gbq) (2.3.3)
# Requirement already satisfied: pyarrow>=4.0.0 in c:\users\salma\miniconda3\lib\site-packages (from pandas_gbq) (22.0.0)
# Requirement already satisfied: pydata-google-auth>=1.5.0 in c:\users\salma\miniconda3\lib\site-packages (from pandas_gbq) (1.9.1)
# Requirement already satisfied: google-api-core<3.0.0,>=2.10.2 in c:\users\salma\miniconda3\lib\site-packages (from pandas_gbq) (2.28.1)
# Requirement already satisfied: google-auth>=2.13.0 in c:\users\salma\miniconda3\lib\site-packages (from pandas_gbq) (2.41.1)
# Requirement already satisfied: google-auth-oauthlib>=0.7.0 in c:\users\salma\miniconda3\lib\site-packages (from pandas_gbq) (1.2.3)
# Requirement already satisfied: google-cloud-bigquery<4.0.0,>=3.4.2 in c:\users\salma\miniconda3\lib\site-packages (from pandas_gbq) (3.38.0)
# Requirement already satisfied: packaging>=22.0.0 in c:\users\salma\appdata\roaming\python\python313\site-packages (from pandas_gbq) (25.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\salma\miniconda3\lib\site-packages (from google-api-core<3.0.0,>=2.10.2->pandas_gbq) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\salma\miniconda3\lib\site-packages (from google-api-core<3.0.0,>=2.10.2->pandas_gbq) (6.33.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\salma\miniconda3\lib\site-packages (from google-api-core<3.0.0,>=2.10.2->pandas_gbq) (1.26.1)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\salma\miniconda3\lib\site-packages (from google-api-core<3.0.0,>=2.10.2->pandas_gbq) (2.32.4)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\salma\miniconda3\lib\site-packages (from google-auth>=2.13.0->pandas_gbq) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\salma\miniconda3\lib\site-packages (from google-auth>=2.13.0->pandas_gbq) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\salma\miniconda3\lib\site-packages (from google-auth>=2.13.0->pandas_gbq) (4.9.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\users\salma\miniconda3\lib\site-packages (from google-cloud-bigquery<4.0.0,>=3.4.2->pandas_gbq) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\users\salma\miniconda3\lib\site-packages (from google-cloud-bigquery<4.0.0,>=3.4.2->pandas_gbq) (2.7.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\users\salma\appdata\roaming\python\python313\site-packages (from google-cloud-bigquery<4.0.0,>=3.4.2->pandas_gbq) (2.9.0.post0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\salma\miniconda3\lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0.0,>=3.4.2->pandas_gbq) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\salma\miniconda3\lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0.0,>=3.4.2->pandas_gbq) (1.76.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\salma\miniconda3\lib\site-packages (from google-resumable-media<3.0.0,>=2.0.0->google-cloud-bigquery<4.0.0,>=3.4.2->pandas_gbq) (1.7.1)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\salma\miniconda3\lib\site-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0.0,>=3.4.2->pandas_gbq) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\salma\appdata\roaming\python\python313\site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery<4.0.0,>=3.4.2->pandas_gbq) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\salma\miniconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.10.2->pandas_gbq) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\salma\miniconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.10.2->pandas_gbq) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\salma\miniconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.10.2->pandas_gbq) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\salma\miniconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.10.2->pandas_gbq) (2025.10.5)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\salma\miniconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=2.13.0->pandas_gbq) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\salma\miniconda3\lib\site-packages (from google-auth-oauthlib>=0.7.0->pandas_gbq) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\salma\miniconda3\lib\site-packages (from pandas>=1.1.4->pandas_gbq) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\salma\miniconda3\lib\site-packages (from pandas>=1.1.4->pandas_gbq) (2025.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\salma\miniconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.7.0->pandas_gbq) (3.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from google.oauth2 import service_account
import pandas_gbq

# %%
# Konfigurasi Bigquery

# Setup Credentials
scopes = ["https://www.googleapis.com/auth/bigquery"]
credentials = service_account.Credentials.from_service_account_file(key_path,
                                                                    scopes=scopes)

# %%
print("columns before:", df_tracks_bq.columns.tolist())

if 'playcount_x' in df_tracks_bq.columns:
    pc_x = df_tracks_bq['playcount_x']
else:
    pc_x = pd.Series(np.nan, index=df_tracks_bq.index)

pc_y = df_tracks_bq['playcount_y'] if 'playcount_y' in df_tracks_bq.columns else pd.Series(np.nan, index=df_tracks_bq.index)

if 'listeners_x' in df_tracks_bq.columns:
    li_x = df_tracks_bq['listeners_x']
else:
    li_x = pd.Series(np.nan, index=df_tracks_bq.index)

li_y = df_tracks_bq['listeners_y'] if 'listeners_y' in df_tracks_bq.columns else pd.Series(np.nan, index=df_tracks_bq.index)

df_tracks_bq['playcount'] = pc_x.fillna(pc_y).fillna(0)
df_tracks_bq['listeners'] = li_x.fillna(li_y).fillna(0)

df_tracks_bq['playcount'] = pd.to_numeric(df_tracks_bq['playcount'], errors='coerce').fillna(0).astype('int64')
df_tracks_bq['listeners'] = pd.to_numeric(df_tracks_bq['listeners'], errors='coerce').fillna(0).astype('int64')

for c in ['playcount_x','playcount_y','listeners_x','listeners_y']:
    if c in df_tracks_bq.columns:
        df_tracks_bq.drop(columns=[c], inplace=True)

print("\ncolumns after:", df_tracks_bq.columns.tolist())
print("\ndtypes:\n", df_tracks_bq.dtypes)
print("\npreview (track_name, artist, playcount, listeners):")
print(df_tracks_bq[['track_name','artist','playcount','listeners']].head(10).to_string(index=False))
print("\nrows:", len(df_tracks_bq))

df_tracks_bq['popularity_score'] = (df_tracks_bq['playcount'] * 0.6) + (df_tracks_bq['listeners'] * 0.4)

print("\npreview with popularity_score:")
print(df_tracks_bq[['track_name','artist','playcount','listeners','popularity_score']].head(8).to_string(index=False))
# Out:
# columns before: ['rank', 'track_name', 'artist', 'genres', 'playcount_x', 'listeners_x', 'url', 'data_type', 'extracted_at', 'genres_clean', 'playcount_y', 'listeners_y']
#
# columns after: ['rank', 'track_name', 'artist', 'genres', 'url', 'data_type', 'extracted_at', 'genres_clean', 'playcount', 'listeners']
#
# dtypes:
#  rank                     int64
# track_name              object
# artist                  object
# genres                  object
# url                     object
# data_type               object
# extracted_at    datetime64[ns]
# genres_clean            object
# playcount                int64
# listeners                int64
# dtype: object
#
# preview (track_name, artist, playcount, listeners):
#          track_name       artist  playcount  listeners
# The Fate of Ophelia Taylor Swift   15914357     779603
# The Fate of Ophelia Taylor Swift   15914357     779603
# The Fate of Ophelia Taylor Swift   15914357     779603
# The Fate of Ophelia Taylor Swift   15914357     779603
# The Fate of Ophelia Taylor Swift   15914357     779603
#      Last Christmas        Wham!   14371272    1912402
#      Last Christmas        Wham!   14371272    1912402
#      Last Christmas        Wham!   14371272    1912402
#      Last Christmas        Wham!   14371272    1912402
#      Last Christmas        Wham!   14371272    1912402
#
# rows: 481
#
# preview with popularity_score:
#          track_name       artist  playcount  listeners  popularity_score
# The Fate of Ophelia Taylor Swift   15914357     779603         9860455.4
# The Fate of Ophelia Taylor Swift   15914357     779603         9860455.4
# The Fate of Ophelia Taylor Swift   15914357     779603         9860455.4
# The Fate of Ophelia Taylor Swift   15914357     779603         9860455.4
# The Fate of Ophelia Taylor Swift   15914357     779603         9860455.4
#      Last Christmas        Wham!   14371272    1912402         9387724.0
#      Last Christmas        Wham!   14371272    1912402         9387724.0
#      Last Christmas        Wham!   14371272    1912402         9387724.0

# %%
pandas_gbq.to_gbq(
    dataframe=df_artists_bq,
    destination_table=f"{dataset_id}.artists",
    project_id=project_id,
    if_exists="replace",
    credentials=credentials
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 14614.30it/s]

# %%
pandas_gbq.to_gbq(
    dataframe=df_genres_bq,
    destination_table=f"{dataset_id}.genres",
    project_id=project_id,
    if_exists="replace",
    credentials=credentials
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 18001.30it/s]

# %%
df_tracks_bq.to_gbq(
    destination_table='data_lastfm_porto2.tracks',
    project_id='portofolio-2-480507',
    if_exists='replace'
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 17403.75it/s]
